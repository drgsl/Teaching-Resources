# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# {c, m, f, s, g}
#
# {c, m, f , s}
# {c, m, f , g}
# {c, m, s , g}
# {c, f, s , g}
# {c, f, s , g}
# {m, f, s , g}
#
#
# {c, m, f}
# {c, m, s}
# {c, m, g}
#
# {c, f, s}
# {c, f, g}
#
# {c, s, g}
#
# {m, f, s}
# {m, f, g}
# {m, s, g}
#
# {f, s, g}
#
#
# {c, m}
# {c, f}
# {c, s}
# {c, g}
#
# {m, f}
# {m, s}
# {m, g}
#
# {f, s}
# {f, g}
#
# {s, g}
