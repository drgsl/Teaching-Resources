# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# Answer:
#
# <!-- Answer: d) -->

# %% [markdown]
# 5 / 2
#
# 1) 5, 2 - sunt int
#
# 5/2 = 2
#
#
# 2) 5, 2 - sunt float
#
# 5.00/2.00 = 2.5
