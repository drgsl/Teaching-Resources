# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# Answer:
#
# <!-- Answer: b) -->

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Answer:
#
# <!-- Answer: b) -->
