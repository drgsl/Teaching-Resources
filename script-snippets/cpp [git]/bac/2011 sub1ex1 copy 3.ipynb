# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# Answer:
#
# <!-- Answer: d) -->

# %% [markdown]
# !(-20>=x) && (x<=-10) || (x>=-5) && !(x>5)
#
# (-20 < x) && (x<=-10) || (x>=-5) &&  (x<=5)
#
#
# x > -20 SI x <= -10 SAU x >=-5 SI x <= 5
#
# (-20, -10] U [-5,5 ]
