# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Answer:
#
# <!-- Answer: b) -->

# %% [markdown]
# d) !(x != y && x != z)
#
# -1*(2 + 3)
#
# = -2 - 3
#
#  !(  (x!=y)  &&  (x!=z)  )
#
#   ( !(x!=y)  || !(x!=z)  )
#
#   (  (x==y)  ||  (x==z)  )
