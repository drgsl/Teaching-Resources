# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Answer:
#
# <!-- Answer: a) -->

# %% [markdown]
# 4/2 + 4%2 - 4/2
#
# 4/2 = 2
#
# 4%2 = 0 pt ca 4/2 = 2 r 0
#
# 4/2 = 2
#
# 2 + 0 - 2 == 0 A

# %% [markdown]
# x = 6
# y = 3
#
# 6/2 + 6%3 - 6/3 = 3 + 0 - 2 = 1 F

# %% [markdown]
# x = 8
#
# y = 4
#
#
# 8/2 + 8%4 - 8/4  =  4 + 0 - 2 = 2
#
# 2 == 0 F

# %% [markdown]
# x = 10
#
# y = 0
#
# 10/2 + 10%0 - 10/0 = 5 + 0 - 0 = 5 F
